# %% [markdown]
# <a href="https://colab.research.google.com/github/am-sudhi/ds/blob/main/TASK%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lets Grow More**
#
# **Task 3**
#
# **Name : SUDHIN RAJ**
#
# **Data Science Internship**
#
# **Stock Market Prediction and Forecast using Stacked LSTM**
#
# **Dataset:** https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv
#
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# **Importing Dataset**

# %%
stmrk = pd.read_csv('https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv')

# %% [markdown]
# **Displaying first 5 rows in the dataset using head()**

# %%
stmrk.head()
# Out:
#          Date    Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 0  2018-09-28  234.05  235.95  ...  233.75               3069914          7162.35
# 1  2018-09-27  234.55  236.80  ...  233.25               5082859         11859.95
# 2  2018-09-26  240.00  240.00  ...  234.25               2240909          5248.60
# 3  2018-09-25  233.30  236.75  ...  236.10               2349368          5503.90
# 4  2018-09-24  233.55  239.20  ...  233.30               3423509          7999.55
#
# [5 rows x 8 columns]

# %%
stmrk.tail()
# Out:
#             Date   Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 2030  2010-07-27  117.6  119.50  ...  118.65                586100           694.98
# 2031  2010-07-26  120.1  121.00  ...  117.60                658440           780.01
# 2032  2010-07-23  121.8  121.95  ...  120.65                281312           340.31
# 2033  2010-07-22  120.3  122.00  ...  120.90                293312           355.17
# 2034  2010-07-21  122.1  123.00  ...  121.55                658666           803.56
#
# [5 rows x 8 columns]

# %%
stmrk.shape
# Out:
# (2035, 8)

# %%
stmrk.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
df=stmrk.sort_values(by=["Date"])
df
# Out:
#             Date    Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 2034  2010-07-21  122.10  123.00  ...  121.55                658666           803.56
# 2033  2010-07-22  120.30  122.00  ...  120.90                293312           355.17
# 2032  2010-07-23  121.80  121.95  ...  120.65                281312           340.31
# 2031  2010-07-26  120.10  121.00  ...  117.60                658440           780.01
# 2030  2010-07-27  117.60  119.50  ...  118.65                586100           694.98
# ...          ...     ...     ...  ...     ...                   ...              ...
# 4     2018-09-24  233.55  239.20  ...  233.30               3423509          7999.55
# 3     2018-09-25  233.30  236.75  ...  236.10               2349368          5503.90
# 2     2018-09-26  240.00  240.00  ...  234.25               2240909          5248.60
# 1     2018-09-27  234.55  236.80  ...  233.25               5082859         11859.95
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#       index        Date    Open  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 0      2034  2010-07-21  122.10  ...  121.55                658666           803.56
# 1      2033  2010-07-22  120.30  ...  120.90                293312           355.17
# 2      2032  2010-07-23  121.80  ...  120.65                281312           340.31
# 3      2031  2010-07-26  120.10  ...  117.60                658440           780.01
# 4      2030  2010-07-27  117.60  ...  118.65                586100           694.98
# ...     ...         ...     ...  ...     ...                   ...              ...
# 2030      4  2018-09-24  233.55  ...  233.30               3423509          7999.55
# 2031      3  2018-09-25  233.30  ...  236.10               2349368          5503.90
# 2032      2  2018-09-26  240.00  ...  234.25               2240909          5248.60
# 2033      1  2018-09-27  234.55  ...  233.25               5082859         11859.95
# ...

# %%
df.describe()
# Out:
#              index         Open  ...  Total Trade Quantity  Turnover (Lacs)
# count  2035.000000  2035.000000  ...          2.035000e+03      2035.000000
# mean   1017.000000   149.713735  ...          2.335681e+06      3899.980565
# std     587.598219    48.664509  ...          2.091778e+06      4570.767877
# min       0.000000    81.100000  ...          3.961000e+04        37.040000
# 25%     508.500000   120.025000  ...          1.146444e+06      1427.460000
# 50%    1017.000000   141.500000  ...          1.783456e+06      2512.030000
# 75%    1525.500000   157.175000  ...          2.813594e+06      4539.015000
# max    2034.000000   327.700000  ...          2.919102e+07     55755.080000
#
# [8 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 2035 non-null   int64
#  1   Date                  2035 non-null   object
#  2   Open                  2035 non-null   float64
#  3   High                  2035 non-null   float64
#  4   Low                   2035 non-null   float64
#  5   Last                  2035 non-null   float64
#  6   Close                 2035 non-null   float64
#  7   Total Trade Quantity  2035 non-null   int64
#  8   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 143.2+ KB

# %% [markdown]
# **DATA VISUALIZATION**

# %%
plt.figure(figsize=(7,6))
plt.plot(df["Close"])

# %%
df_close=df["Close"]
df_close
# Out:
# 0       121.55
# 1       120.90
# 2       120.65
# 3       117.60
# 4       118.65
#          ...
# 2030    233.30
# 2031    236.10
# 2032    234.25
# 2033    233.25
# 2034    233.75
# Name: Close, Length: 2035, dtype: float64

# %% [markdown]
# **DATA PREPROCESSING**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler(feature_range=(0,1))
scldat= scaler.fit_transform(np.array(df_close).reshape(-1,1))
scldat
# Out:
# array([[0.16584967],
#        [0.16319444],
#        [0.1621732 ],
#        ...,
#        [0.62622549],
#        [0.62214052],
#        [0.62418301]])

# %% [markdown]
# **CREATING TRAINING AND TESTING DATA**

# %%
training_size = int(len(scldat)*0.70)
test_size = len(scldat) - training_size


train_data = scldat[0:training_size,:]
test_data = scldat[training_size:len(scldat), :1]

# %%
training_size,train_data
# Out:
# (1424, array([[0.16584967],
#         [0.16319444],
#         [0.1621732 ],
#         ...,
#         [0.15012255],
#         [0.15747549],
#         [0.15277778]]))

# %%
test_size,test_data
# Out:
# (611, array([[0.1621732 ],
#         [0.15951797],
#         [0.16707516],
#         [0.15992647],
#         [0.16053922],
#         [0.16441993],
#         [0.16687092],
#         [0.1693219 ],
#         [0.16074346],
#         [0.15972222],
#         [0.16401144],
#         [0.15727124],
#         [0.14705882],
#         [0.14460784],
#         [0.15175654],
#         [0.15441176],
#         [0.15216503],
#         [0.14848856],
#         [0.15522876],
#         [0.15767974],
#         [0.1621732 ],
#         [0.16094771],
#         [0.16339869],
#         [0.15931373],
#         [0.15972222],
#         [0.16115196],
#         [0.16666667],
#         [0.15747549],
#         [0.15379902],
#         [0.14848856],
#         [0.15114379],
#         [0.1503268 ],
#         [0.15155229],
#         [0.15645425],
#         [0.16033497],
#         [0.1566585 ],
#         [0.15686275],
#         [0.17749183],
#         [0.17973856],
#         [0.1744281 ],
#         [0.19281046],
# ...

# %%
def matrix(dataset, time_step=1):
  dataX, dataY = [], []
  for i in range(len(dataset)-time_step-1):
    a = dataset[i:(i+time_step), 0]
    dataX.append(a)
    dataY.append(dataset[i + time_step, 0])

  return np.array(dataX), np.array(dataY)

# %%
time_step = 100
x_train, y_train = matrix(train_data, time_step)
x_test, y_test = matrix(test_data, time_step)

# %%
x_train.shape,x_test.shape
# Out:
# ((1323, 100), (510, 100))

# %%
y_train.shape,y_test.shape
# Out:
# ((1323,), (510,))

# %% [markdown]
# **RESHAPING THE DATA**

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# %% [markdown]
# **CREATING LSTM MODEL**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100,1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, validation_split=0.1, epochs= 60, batch_size=64, verbose = 1)
# Out:
# Epoch 1/60
# 19/19 [==============================] - 11s 269ms/step - loss: 0.0126 - val_loss: 0.0013
# Epoch 2/60
# 19/19 [==============================] - 4s 189ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 3/60
# 19/19 [==============================] - 4s 189ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 4/60
# 19/19 [==============================] - 4s 187ms/step - loss: 9.2580e-04 - val_loss: 0.0012
# Epoch 5/60
# 19/19 [==============================] - 4s 188ms/step - loss: 8.6718e-04 - val_loss: 0.0012
# Epoch 6/60
# 19/19 [==============================] - 4s 189ms/step - loss: 8.3494e-04 - val_loss: 0.0012
# Epoch 7/60
# 19/19 [==============================] - 4s 191ms/step - loss: 8.0975e-04 - val_loss: 0.0011
# Epoch 8/60
# 19/19 [==============================] - 4s 189ms/step - loss: 7.8759e-04 - val_loss: 0.0011
# Epoch 9/60
# 19/19 [==============================] - 4s 187ms/step - loss: 7.7078e-04 - val_loss: 0.0010
# Epoch 10/60
# ...

# %%
test_predict = model.predict(x_test)

# %%
inverse_predict = scaler.inverse_transform(test_predict)
inverse_predict
# Out:
# array([[142.21986 ],
#        [142.39636 ],
#        [141.48615 ],
#        [138.78862 ],
#        [137.0928  ],
#        [136.59413 ],
#        [137.83777 ],
#        [139.48691 ],
#        [139.90471 ],
#        [139.47986 ],
#        [139.16985 ],
#        [140.32858 ],
#        [141.16397 ],
#        [142.73643 ],
#        [144.93886 ],
#        [142.92622 ],
#        [140.3594  ],
#        [139.92735 ],
#        [140.62688 ],
#        [145.71387 ],
#        [150.28703 ],
#        [152.44585 ],
#        [152.6309  ],
#        [150.39265 ],
#        [150.09436 ],
#        [149.94572 ],
#        [150.42876 ],
#        [152.1839  ],
#        [152.95712 ],
#        [152.90659 ],
#        [153.23271 ],
#        [152.04533 ],
#        [148.74269 ],
#        [142.99483 ],
#        [139.57321 ],
#        [138.71115 ],
#        [139.00433 ],
#        [138.26945 ],
#        [135.93077 ],
#        [132.18509 ],
#        [129.60419 ],
#        [128.43385 ],
#        [126.4394  ],
# ...

# %% [markdown]
# **MEAN SQUARED ERROR**

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_sqr_error = mean_squared_error(y_test, test_predict)
print("The Mean Squared Error is: ", mean_sqr_error)
# Out:
# The Mean Squared Error is:  0.0021363071238277354
